# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from xgboost import XGBRegressor 
import category_encoders as ce
from sklearn.compose import ColumnTransformer
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("gurgaon_properties_post_feature_selection.csv")

# %%
df.head()
# Out:
#        sector property_type  price  bedRoom  bathroom  builtUpArea  \
# 0   sector 49          flat   2.45      3.0       3.0       1865.0
# 1  sector 109         house   6.10      5.0       6.0       2430.0
# 2    sector 1          flat   1.65      4.0       3.0       3111.0
# 3    sector 7         house   0.66      3.0       1.0        550.0
# 4  sector 37d          flat   1.40      3.0       3.0       1711.0
#
#    servant room  study room luxury_category
# 0             0           1             Low
# 1             1           0             Low
# 2             1           0             Low
# 3             0           0             Low
# 4             0           0          Medium

# %%
df['servant room'] = df['servant room'].replace({0:'No', 1:'Yes'})
df['study room'] = df['study room'].replace({0:'No', 1:'Yes'})

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
y_transformed = np.log1p(y)

# %% [markdown]
# ## Ordinal Encoding

# %%
columns_to_encode = ['sector', 'property_type', 'luxury_category', 'servant room', 'study room']

# %% [markdown]
# ## creating a column transformer for preprocessing

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'builtUpArea']),
        ('cat', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), columns_to_encode)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ## Creating a pipeline

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %% [markdown]
# # k-fold cross validation

# %%
k_fold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=k_fold, scoring='r2')

# %%
r2_score, standard_deviation = scores.mean(), scores.std()

# %%
r2_score
# Out:
# 0.731477113308337

# %%
standard_deviation
# Out:
# 0.029313978928780106

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, test_size=0.2, random_state=42)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'builtUpArea']),
#                                                  ('cat',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['sector', 'property_type',
#                                                    'luxury_category',
#                                                    'servant room',
#                                                    'study room'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
y_pred = np.expm1(y_pred)

# %%
mae = mean_absolute_error(np.expm1(y_test), y_pred)

# %%
mae
# Out:
# 0.9779014138976233

# %%
def scorer(model_name, model):

    output = {}
    
    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', model)
    ])

    k_fold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=k_fold, scoring='r2')
    r2_score, standard_deviation = scores.mean(), scores.std()

    output[model_name] = {'r2_score':r2_score}
    output[model_name].update(std=standard_deviation)

    pipeline.fit(X_train, y_train)
    
    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)
    
    mae = mean_absolute_error(np.expm1(y_test), y_pred)

    output[model_name].update(mae_pred=mae)

    return output

# %%
scorer('LinearRegression', LinearRegression())
# Out:
# {'LinearRegression': {'r2_score': 0.731477113308337,
#   'std': 0.029313978928780106,
#   'mae_pred': 0.9779014138976233}}

# %%
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.linear_model import Ridge, Lasso
from xgboost import XGBRegressor 
import category_encoders as ce
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor

# %%
model_dict = {
    'lin_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'lasso':Lasso(),
    'decision Tree':DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreeRegressor(),
    'gradientBoosting':GradientBoostingRegressor(),
    'adaboost':AdaBoostRegressor(),
    'mlp':MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
def try_all_models(model_dict):
    model_output = []
    for model_name, model in model_dict.items():
        model_output.append(scorer(model_name, model))
    df = pd.DataFrame({
        'models': list(model_dict.keys()),
        'r2_train': list(map(lambda x: list(x.values())[0]['r2_score'], model_output)),
        'mae_pred': list(map(lambda x: list(x.values())[0]['mae_pred'], model_output)),
        'std_train': list(map(lambda x: list(x.values())[0]['std'], model_output)),
        }).sort_values(by='mae_pred', ascending=True)
    print(df)

# %%
try_all_models(model_dict)
# Out:
#               models  r2_train  mae_pred  std_train
# 5      random forest  0.877645  0.495946   0.028737
# 10           xgboost  0.891389  0.512031   0.021700
# 7   gradientBoosting  0.873360  0.577891   0.019694
# 4      decision Tree  0.786373  0.662034   0.036705
# 9                mlp  0.774642  0.762506   0.046902
# 6        extra trees  0.735607  0.781435   0.042867
# 8           adaboost  0.756361  0.853835   0.018482
# 2              ridge  0.731482  0.977895   0.029285
# 0            lin_reg  0.731477  0.977901   0.029314
# 1                svr  0.723545  0.979895   0.029877
# 3              lasso  0.070839  1.639397   0.019488

# %% [markdown]
# # OneHotEncoding

# %%
columns_to_encode
# Out:
# ['sector', 'property_type', 'luxury_category', 'servant room', 'study room']

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'builtUpArea']),
        ('cat1', OneHotEncoder(handle_unknown='ignore', drop='first'), ['sector', 'property_type', 'servant room', 'study room']),
        ('cat2', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ['luxury_category'])
    ],
    remainder='passthrough'
)

# %%
try_all_models(model_dict)
# Out:
#               models  r2_train  mae_pred  std_train
# 9                mlp  0.895321  0.485545   0.017747
# 10           xgboost  0.893772  0.517147   0.020206
# 5      random forest  0.881253  0.517641   0.025456
# 1                svr  0.892784  0.520650   0.018451
# 7   gradientBoosting  0.860809  0.598972   0.020703
# 6        extra trees  0.814721  0.611834   0.037278
# 4      decision Tree  0.815784  0.661059   0.041743
# 0            lin_reg  0.855245  0.677911   0.019053
# 2              ridge  0.855903  0.691937   0.017828
# 8           adaboost  0.727617  0.911575   0.025785
# 3              lasso -0.002128  1.675962   0.002720

# %% [markdown]
# # Using PCA

# %%
from sklearn.decomposition import PCA

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'builtUpArea']),
        ('cat1', OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=False), ['sector', 'property_type', 'servant room', 'study room']),
        ('cat2', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ['luxury_category'])
    ],
    remainder='passthrough'
)

# %%
def scorer(model_name, model):

    output = {}
    
    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', model)
    ])

    k_fold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=k_fold, scoring='r2')
    r2_score, standard_deviation = scores.mean(), scores.std()

    output[model_name] = {'r2_score':r2_score}
    output[model_name].update(std=standard_deviation)

    pipeline.fit(X_train, y_train)
    
    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)
    
    mae = mean_absolute_error(np.expm1(y_test), y_pred)

    output[model_name].update(mae_pred=mae)

    return output

# %%
try_all_models(model_dict)
# Out:
#               models  r2_train  mae_pred  std_train
# 9                mlp  0.860585  0.598068   0.024203
# 1                svr  0.855484  0.601614   0.031048
# 5      random forest  0.856754  0.620005   0.019638
# 10           xgboost  0.851233  0.621268   0.023046
# 7   gradientBoosting  0.844215  0.657784   0.021621
# 4      decision Tree  0.711912  0.800376   0.046222
# 0            lin_reg  0.799658  0.864299   0.024576
# 2              ridge  0.799701  0.864451   0.024571
# 6        extra trees  0.719772  0.881161   0.052242
# 8           adaboost  0.732046  0.883801   0.024328
# 3              lasso -0.002128  1.675962   0.002720

# %% [markdown]
# # Target Encoding

# %%
import category_encoders as ce

# %%
columns_to_encode
# Out:
# ['sector', 'property_type', 'luxury_category', 'servant room', 'study room']

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'builtUpArea']),
        ('target_enc', ce.TargetEncoder(), ['sector', 'property_type', 'servant room', 'study room']),
        ('cat2', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ['luxury_category']),
    ],
    remainder='passthrough'
)

# %%
def scorer(model_name, model):

    output = {}
    
    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', model)
    ])

    k_fold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=k_fold, scoring='r2')
    r2_score, standard_deviation = scores.mean(), scores.std()

    output[model_name] = {'r2_score':r2_score}
    output[model_name].update(std=standard_deviation)

    pipeline.fit(X_train, y_train)
    
    y_pred = pipeline.predict(X_test)

    y_pred = np.expm1(y_pred)
    
    mae = mean_absolute_error(np.expm1(y_test), y_pred)

    output[model_name].update(mae_pred=mae)

    return output

# %%
try_all_models(model_dict)

# %%
xgb = XGBRegressor()

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ('num', StandardScaler(), ['bedRoom', 'bathroom', 'builtUpArea']),
        ('cat1', OneHotEncoder(handle_unknown='ignore', drop='first'), ['sector', 'property_type', 'servant room', 'study room']),
        ('cat2', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), ['luxury_category']),
        ('target_enc', ce.TargetEncoder(), ['sector'])
    ],
    remainder='passthrough'
)

# %%
 pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', xgb)
    ])

# %%
pipeline.fit(X, y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedRoom', 'bathroom',
#                                                    'builtUpArea']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['sector', 'property_type',
#                                                    'servant room',
#                                                    'study room']),
#                                                  ('cat2',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['luxury_c...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=None, n_jobs=None,
#                               num_parallel_tree=None, ...))])

# %%
import joblib
joblib.dump(pipeline, 'model.joblib')
# Out:
# ['model.joblib']

# %%
X.to_csv('df.csv', index=False)

# %%
# %conda list
# Out:
# # packages in environment at /opt/anaconda3/envs/clean_nlp_env:
# #
# # Name                    Version                   Build  Channel
# absl-py                   2.2.0              pyhd8ed1ab_0    conda-forge
# accelerate                1.5.2              pyhd8ed1ab_0    conda-forge
# adwaita-icon-theme        48.1                     unix_0    conda-forge
# aiohappyeyeballs          2.6.1              pyhd8ed1ab_0    conda-forge
# aiohttp                   3.11.18         py310hc74094e_0    conda-forge
# aiosignal                 1.3.2              pyhd8ed1ab_0    conda-forge
# alembic                   1.16.1             pyhd8ed1ab_0    conda-forge
# altair                    5.5.0              pyhd8ed1ab_1    conda-forge
# annotated-types           0.7.0              pyhd8ed1ab_1    conda-forge
# anthropic                 0.57.1                   pypi_0    pypi
# antlr-python-runtime      4.9.3              pyhd8ed1ab_1    conda-forge
# anyio                     4.9.0              pyh29332c3_0    conda-forge
# aom                       3.9.1                h7bae524_0    conda-forge
# appdirs                   1.4.4                    pypi_0    pypi
# appnope                   0.1.4              pyhd8ed1ab_1    conda-forge
# argcomplete               3.6.2                    pypi_0    pypi
# argon2-cffi               25.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0          py310h493c2e1_5    conda-forge
# arrow                     1.3.0              pyhd8ed1ab_1    conda-forge
# asgiref                   3.8.1                    pypi_0    pypi
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# astunparse                1.6.3              pyhd8ed1ab_3    conda-forge
# async-lru                 2.0.5              pyh29332c3_0    conda-forge
# async-timeout             4.0.3                    pypi_0    pypi
# atk-1.0                   2.38.0               hd03087b_2    conda-forge
# attr                      0.3.1                    pypi_0    pypi
# attrs                     25.3.0             pyh71513ae_0    conda-forge
# aws-c-auth                0.8.6                h660070d_4    conda-forge
# aws-c-cal                 0.8.7                h8f38403_0    conda-forge
# aws-c-common              0.12.0               h5505292_0    conda-forge
# aws-c-compression         0.3.1                hd84a0f8_2    conda-forge
# aws-c-event-stream        0.5.4                h3c33643_2    conda-forge
# aws-c-http                0.9.4                hedcc1e3_4    conda-forge
# aws-c-io                  0.17.0               ha705ebb_6    conda-forge
# aws-c-mqtt                0.12.2               h82c6c6a_2    conda-forge
# aws-c-s3                  0.7.13               hb857f95_2    conda-forge
# aws-c-sdkutils            0.2.3                hd84a0f8_2    conda-forge
# aws-checksums             0.2.3                hd84a0f8_2    conda-forge
# aws-crt-cpp               0.31.0               h7378f02_4    conda-forge
# aws-sdk-cpp               1.11.510             hf067f9e_3    conda-forge
# azure-core                1.34.0                   pypi_0    pypi
# azure-core-cpp            1.14.0               hd50102c_0    conda-forge
# azure-identity-cpp        1.10.0               hc602bab_0    conda-forge
# azure-storage-blob        12.25.1                  pypi_0    pypi
# azure-storage-blobs-cpp   12.13.0              h7585a09_1    conda-forge
# azure-storage-common-cpp  12.8.0               h9ca1f76_1    conda-forge
# azure-storage-files-datalake-cpp 12.12.0              hcdd55da_1    conda-forge
# babel                     2.17.0             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0                    pypi_0    pypi
# beautifulsoup4            4.13.4             pyha770c72_0    conda-forge
# black                     25.1.0                   pypi_0    pypi
# bleach                    5.0.1                    pypi_0    pypi
# bleach-with-css           6.2.0                h82add2a_4    conda-forge
# blinker                   1.9.0              pyhff2d567_0    conda-forge
# boto                      2.49.0                   pypi_0    pypi
# boto3                     1.38.41                  pypi_0    pypi
# botocore                  1.38.41                  pypi_0    pypi
# brotli                    1.1.0                hd74edd7_2    conda-forge
# brotli-bin                1.1.0                hd74edd7_2    conda-forge
# brotli-python             1.1.0           py310hb4ad77e_2    conda-forge
# bs4                       4.13.4               hd8ed1ab_0    conda-forge
# bzip2                     1.0.8                h99b78c6_7    conda-forge
# c-ares                    1.34.5               h5505292_0    conda-forge
# ca-certificates           2025.7.9             hbd8a1cb_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cachetools                5.5.2              pyhd8ed1ab_0    conda-forge
# cairo                     1.18.4               h6a3b0d2_0    conda-forge
# category_encoders         2.8.1              pyh1646c32_0    conda-forge
# certifi                   2025.7.9           pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py310h497396d_0    conda-forge
# charset-normalizer        3.4.2              pyhd8ed1ab_0    conda-forge
# click                     8.1.8              pyh707e725_0    conda-forge
# cloudpickle               3.1.1              pyhd8ed1ab_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_1    conda-forge
# colorlog                  6.9.0              pyh707e725_1    conda-forge
# comm                      0.2.2              pyhd8ed1ab_1    conda-forge
# contourpy                 1.3.2           py310h7f4e7e6_0    conda-forge
# cpython                   3.10.17         py310hd8ed1ab_0    conda-forge
# cryptography              44.0.3          py310h69cbf43_0    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_1    conda-forge
# dataclasses               0.8                pyhc8e2a94_3    conda-forge
# datamodel-code-generator  0.26.1                   pypi_0    pypi
# datasets                  2.19.1             pyhd8ed1ab_0    conda-forge
# dav1d                     1.2.1                hb547adb_0    conda-forge
# debugpy                   1.8.14          py310h853098b_0    conda-forge
# decorator                 5.2.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# detectron2                0.6             cpu_py310h0d7db3e_13    conda-forge
# dill                      0.3.8              pyhd8ed1ab_0    conda-forge
# distro                    1.9.0              pyhd8ed1ab_1    conda-forge
# django                    5.1.11                   pypi_0    pypi
# django-annoying           0.10.6                   pypi_0    pypi
# django-cors-headers       4.7.0                    pypi_0    pypi
# django-csp                3.7                      pypi_0    pypi
# django-debug-toolbar      3.2.1                    pypi_0    pypi
# django-environ            0.10.0                   pypi_0    pypi
# django-extensions         3.2.3                    pypi_0    pypi
# django-filter             24.3                     pypi_0    pypi
# django-migration-linter   5.2.0                    pypi_0    pypi
# django-model-utils        4.1.1                    pypi_0    pypi
# django-ranged-fileresponse 0.1.2                    pypi_0    pypi
# django-rq                 2.10.3                   pypi_0    pypi
# django-storages           1.12.3                   pypi_0    pypi
# django-user-agents        0.4.0                    pypi_0    pypi
# djangorestframework       3.15.2                   pypi_0    pypi
# djangorestframework-simplejwt 5.4.0                    pypi_0    pypi
# dnspython                 2.7.0                    pypi_0    pypi
# docopt                    0.6.2              pyhd8ed1ab_2    conda-forge
# drf-dynamic-fields        0.3.0                    pypi_0    pypi
# drf-flex-fields           0.9.5                    pypi_0    pypi
# drf-generators            0.3.0                    pypi_0    pypi
# email-validator           2.2.0                    pypi_0    pypi
# epoxy                     1.5.10               h1c322ee_1    conda-forge
# et_xmlfile                2.0.0              pyhd8ed1ab_1    conda-forge
# exceptiongroup            1.2.2                    pypi_0    pypi
# executing                 2.2.0              pyhd8ed1ab_0    conda-forge
# expiringdict              1.2.2                    pypi_0    pypi
# faker                     37.4.0                   pypi_0    pypi
# fftw                      3.3.10          nompi_h6637ab6_110    conda-forge
# filelock                  3.18.0             pyhd8ed1ab_0    conda-forge
# filetype                  1.2.0                    pypi_0    pypi
# flask                     1.1.2                    pypi_0    pypi
# flask_cors                4.0.0              pyhd8ed1ab_0    conda-forge
# flatbuffers               24.12.23             h28594ff_0    conda-forge
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 h77eed37_3    conda-forge
# fontconfig                2.15.0               h1383a14_1    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.57.0          py310hc74094e_0    conda-forge
# fqdn                      1.5.1              pyhd8ed1ab_1    conda-forge
# freetype                  2.13.3               hce30654_1    conda-forge
# fribidi                   1.0.10               h27ca646_0    conda-forge
# frozenlist                1.5.0           py310hc74094e_1    conda-forge
# fsspec                    2024.3.1           pyhca7485f_0    conda-forge
# future                    1.0.0              pyhd8ed1ab_2    conda-forge
# fvcore                    0.1.5.post20221221    pyhd8ed1ab_0    conda-forge
# gast                      0.6.0              pyhd8ed1ab_0    conda-forge
# gdk-pixbuf                2.42.12              h7ddc832_0    conda-forge
# gensim                    4.3.3           py310hd4a36ba_0    conda-forge
# genson                    1.3.0                    pypi_0    pypi
# gflags                    2.2.2             hf9b8971_1005    conda-forge
# ghostscript               10.04.0              hf9b8971_0    conda-forge
# giflib                    5.2.2                h93a5062_0    conda-forge
# gitdb                     4.0.12             pyhd8ed1ab_0    conda-forge
# gitpython                 3.1.44             pyhff2d567_0    conda-forge
# glib-tools                2.84.2               h1dc7a0c_0    conda-forge
# glog                      0.7.1                heb240a5_0    conda-forge
# gmp                       6.3.0                h7bae524_2    conda-forge
# gmpy2                     2.2.1           py310h805dbd7_0    conda-forge
# google-ai-generativelanguage 0.6.15                   pypi_0    pypi
# google-api-core           2.24.2             pyhd8ed1ab_0    conda-forge
# google-api-python-client  2.176.0                  pypi_0    pypi
# google-auth               2.40.1             pyhd8ed1ab_0    conda-forge
# google-auth-httplib2      0.2.0                    pypi_0    pypi
# google-cloud-appengine-logging 1.6.2                    pypi_0    pypi
# google-cloud-audit-log    0.3.2                    pypi_0    pypi
# google-cloud-core         2.4.3              pyhd8ed1ab_0    conda-forge
# google-cloud-logging      3.12.1                   pypi_0    pypi
# google-cloud-storage      2.19.0                   pypi_0    pypi
# google-crc32c             1.7.1           py310hb48017c_0    conda-forge
# google-generativeai       0.8.5                    pypi_0    pypi
# google-pasta              0.2.0              pyhd8ed1ab_2    conda-forge
# google-resumable-media    2.7.2              pyhd8ed1ab_2    conda-forge
# googleapis-common-protos  1.70.0             pyhd8ed1ab_0    conda-forge
# graphite2                 1.3.14               h286801f_0    conda-forge
# graphviz                  12.2.1               hff64154_1    conda-forge
# greenlet                  3.2.3           py310h853098b_0    conda-forge
# grpc-google-iam-v1        0.14.2                   pypi_0    pypi
# grpcio                    1.73.0                   pypi_0    pypi
# grpcio-status             1.71.2                   pypi_0    pypi
# gtk3                      3.24.43              h07173f4_5    conda-forge
# gts                       0.7.6                he42f4ea_4    conda-forge
# h11                       0.16.0             pyhd8ed1ab_0    conda-forge
# h2                        4.2.0              pyhd8ed1ab_0    conda-forge
# h5py                      3.13.0          nompi_py310h8ca6390_100    conda-forge
# harfbuzz                  11.2.1               hab40de2_0    conda-forge
# hdf5                      1.14.3          nompi_ha698983_109    conda-forge
# hicolor-icon-theme        0.17                 hce30654_2    conda-forge
# hpack                     4.1.0              pyhd8ed1ab_0    conda-forge
# htmlmin                   0.1.12             pyhca7485f_2    conda-forge
# httpcore                  1.0.9              pyh29332c3_0    conda-forge
# httplib2                  0.22.0                   pypi_0    pypi
# httpx                     0.28.1             pyhd8ed1ab_0    conda-forge
# huggingface_hub           0.30.2             pyhd8ed1ab_0    conda-forge
# humansignal-drf-yasg      1.21.10.post1            pypi_0    pypi
# hydra-core                1.3.2              pyhd8ed1ab_1    conda-forge
# hyperframe                6.1.0              pyhd8ed1ab_0    conda-forge
# icu                       75.1                 hfee45f7_0    conda-forge
# idna                      3.10               pyhd8ed1ab_1    conda-forge
# ijson                     3.4.0                    pypi_0    pypi
# imagehash                 4.3.2              pyhd8ed1ab_0    conda-forge
# imagemagick               7.1.1_47         gpl_h1845f4d_0    conda-forge
# importlib-metadata        8.6.1              pyha770c72_0    conda-forge
# importlib_metadata        8.6.1                hd8ed1ab_0    conda-forge
# importlib_resources       6.5.2              pyhd8ed1ab_0    conda-forge
# inflect                   5.6.2                    pypi_0    pypi
# inflection                0.5.1                    pypi_0    pypi
# iopath                    0.1.9              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.29.5             pyh57ce528_0    conda-forge
# ipython                   8.12.3                   pypi_0    pypi
# ipywidgets                8.1.7              pyhd8ed1ab_0    conda-forge
# isodate                   0.7.2                    pypi_0    pypi
# isoduration               20.11.0            pyhd8ed1ab_1    conda-forge
# isort                     5.13.2                   pypi_0    pypi
# itsdangerous              2.0.1                    pypi_0    pypi
# jbig                      2.1               h3422bc3_2003    conda-forge
# jedi                      0.19.2             pyhd8ed1ab_1    conda-forge
# jinja2                    3.0.3                    pypi_0    pypi
# jiter                     0.10.0          py310hde4708a_0    conda-forge
# jmespath                  1.0.1                    pypi_0    pypi
# joblib                    1.5.0              pyhd8ed1ab_0    conda-forge
# jsf                       0.11.2                   pypi_0    pypi
# json5                     0.12.0             pyhd8ed1ab_0    conda-forge
# jsonpatch                 1.33                     pypi_0    pypi
# jsonpointer               3.0.0           py310hbe9552e_1    conda-forge
# jsonschema                4.24.0             pyhd8ed1ab_0    conda-forge
# jsonschema-specifications 2025.4.1           pyh29332c3_0    conda-forge
# jsonschema-with-format-nongpl 4.24.0               hd8ed1ab_0    conda-forge
# jupyter-core              5.7.2                    pypi_0    pypi
# jupyter-lsp               2.2.5              pyhe01879c_2    conda-forge
# jupyter_client            8.6.3              pyhd8ed1ab_1    conda-forge
# jupyter_core              5.8.1              pyh31011fe_0    conda-forge
# jupyter_events            0.12.0             pyh29332c3_0    conda-forge
# jupyter_server            2.16.0             pyhe01879c_0    conda-forge
# jupyter_server_terminals  0.5.3              pyhd8ed1ab_1    conda-forge
# jupyterlab                4.1.6              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_2    conda-forge
# jupyterlab_server         2.24.0             pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        3.0.15             pyhd8ed1ab_0    conda-forge
# keras                     3.9.2              pyh753f3f9_0    conda-forge
# kiwisolver                1.4.7           py310h7306fd8_0    conda-forge
# krb5                      1.21.3               h237132a_0    conda-forge
# label-studio              1.19.0                   pypi_0    pypi
# label-studio-ml           1.0.9                    pypi_0    pypi
# label-studio-sdk          1.0.16                   pypi_0    pypi
# label-studio-tools        0.0.4                    pypi_0    pypi
# langchain                 0.3.26                   pypi_0    pypi
# langchain-anthropic       0.3.17                   pypi_0    pypi
# langchain-core            0.3.68                   pypi_0    pypi
# langchain-google-genai    2.0.10                   pypi_0    pypi
# langchain-huggingface     0.3.0                    pypi_0    pypi
# langchain-openai          0.3.27                   pypi_0    pypi
# langchain-text-splitters  0.3.8                    pypi_0    pypi
# langsmith                 0.4.5                    pypi_0    pypi
# launchdarkly-server-sdk   8.2.1                    pypi_0    pypi
# lcms2                     2.17                 h7eeda09_0    conda-forge
# lerc                      4.0.0                hd64df32_1    conda-forge
# libabseil                 20240722.0      cxx17_h07bc746_4    conda-forge
# libaec                    1.1.3                hebf3989_0    conda-forge
# libarrow                  19.0.1           h9828ad4_3_cpu    conda-forge
# libarrow-acero            19.0.1           hf07054f_3_cpu    conda-forge
# libarrow-dataset          19.0.1           hf07054f_3_cpu    conda-forge
# libarrow-substrait        19.0.1           h4239455_3_cpu    conda-forge
# libavif16                 1.3.0                hf1e31eb_0    conda-forge
# libblas                   3.9.0           20_osxarm64_openblas    conda-forge
# libbrotlicommon           1.1.0                hd74edd7_2    conda-forge
# libbrotlidec              1.1.0                hd74edd7_2    conda-forge
# libbrotlienc              1.1.0                hd74edd7_2    conda-forge
# libcblas                  3.9.0           20_osxarm64_openblas    conda-forge
# libcrc32c                 1.1.2                hbdafb3b_0    conda-forge
# libcurl                   8.13.0               h73640d1_0    conda-forge
# libcxx                    20.1.4               ha82da77_0    conda-forge
# libde265                  1.0.15               h2ffa867_0    conda-forge
# libdeflate                1.23                 h5773f1b_0    conda-forge
# libedit                   3.1.20250104    pl5321hafb1f1b_0    conda-forge
# libev                     4.33                 h93a5062_2    conda-forge
# libevent                  2.1.12               h2757513_1    conda-forge
# libexpat                  2.7.0                h286801f_0    conda-forge
# libffi                    3.4.6                h1da3d7d_1    conda-forge
# libfreetype               2.13.3               hce30654_1    conda-forge
# libfreetype6              2.13.3               h1d14073_1    conda-forge
# libgd                     2.3.3               hb2c3a21_11    conda-forge
# libgfortran               14.2.0             heb5dd2a_105    conda-forge
# libgfortran5              14.2.0             h2c44a93_105    conda-forge
# libglib                   2.84.2               hbec27ea_0    conda-forge
# libgoogle-cloud           2.36.0               hdbe95d5_0    conda-forge
# libgoogle-cloud-storage   2.36.0               h7081f7f_0    conda-forge
# libgrpc                   1.67.1               h0a426d6_2    conda-forge
# libheif                   1.19.7          gpl_h79e6334_100    conda-forge
# libiconv                  1.18                 hfe07756_1    conda-forge
# libintl                   0.24.1               h493aca8_0    conda-forge
# libjpeg-turbo             3.1.0                h5505292_0    conda-forge
# liblapack                 3.9.0           20_osxarm64_openblas    conda-forge
# libllvm14                 14.0.6               hd1a9a77_4    conda-forge
# liblzma                   5.8.1                h39f12f2_1    conda-forge
# liblzma-devel             5.8.1                h39f12f2_1    conda-forge
# libnghttp2                1.64.0               h6d7220d_0    conda-forge
# libopenblas               0.3.25          openmp_h6c19121_0    conda-forge
# libopentelemetry-cpp      1.18.0               h0c05b2d_1    conda-forge
# libopentelemetry-cpp-headers 1.18.0               hce30654_1    conda-forge
# libparquet                19.0.1           h636d7b7_3_cpu    conda-forge
# libpng                    1.6.47               h3783ad8_0    conda-forge
# libprotobuf               5.28.3               h3bd63a1_1    conda-forge
# libre2-11                 2024.07.02           h07bc746_2    conda-forge
# librsvg                   2.58.4               h266df6f_3    conda-forge
# libsodium                 1.0.20               h99b78c6_0    conda-forge
# libsqlite                 3.49.1               h3f77e49_2    conda-forge
# libssh2                   1.11.1               h1590b86_0    conda-forge
# libthrift                 0.21.0               h64651cc_0    conda-forge
# libtiff                   4.7.0                h551f018_4    conda-forge
# libtorch                  2.6.0           cpu_generic_hb0d28ef_1    conda-forge
# libutf8proc               2.10.0               hda25de7_0    conda-forge
# libuv                     1.51.0               h5505292_0    conda-forge
# libwebp                   1.5.0                h1618228_0    conda-forge
# libwebp-base              1.5.0                h2471fea_0    conda-forge
# libxcb                    1.17.0               hdb1d25a_0    conda-forge
# libxgboost                3.0.2            cpu_hf17a1b1_0    conda-forge
# libxml2                   2.13.7               h52572c6_1    conda-forge
# libxslt                   1.1.39               h223e5b9_0    conda-forge
# libzlib                   1.3.1                h8359307_2    conda-forge
# llvm-openmp               20.1.4               hdb05f8b_0    conda-forge
# llvmlite                  0.43.0          py310h9fcfb1b_1    conda-forge
# lockfile                  0.12.2                   pypi_0    pypi
# lxml                      5.4.0           py310hb092e44_0    conda-forge
# lxml-html-clean           0.4.2                    pypi_0    pypi
# lz4-c                     1.10.0               h286801f_1    conda-forge
# mako                      1.3.10             pyhd8ed1ab_0    conda-forge
# markdown                  3.8                pyhd8ed1ab_0    conda-forge
# markdown-it-py            3.0.0              pyhd8ed1ab_1    conda-forge
# markupsafe                3.0.2           py310hc74094e_1    conda-forge
# matplotlib                3.6.3           py310hb6292c7_0    conda-forge
# matplotlib-base           3.6.3           py310h78c5c2f_0    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_1    conda-forge
# mdurl                     0.1.2              pyhd8ed1ab_1    conda-forge
# mistune                   3.1.3              pyh29332c3_0    conda-forge
# ml_dtypes                 0.4.0           py310hfd37619_2    conda-forge
# mpc                       1.3.1                h8f1351a_1    conda-forge
# mpfr                      4.2.1                hb693164_3    conda-forge
# mpmath                    1.3.0              pyhd8ed1ab_1    conda-forge
# multidict                 6.4.3           py310hdf261b0_0    conda-forge
# multimethod               1.9.1              pyhd8ed1ab_0    conda-forge
# multiprocess              0.70.16         py310h493c2e1_1    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mypy-extensions           1.1.0                    pypi_0    pypi
# namex                     0.0.9              pyhd8ed1ab_0    conda-forge
# narwhals                  1.42.0             pyhe01879c_0    conda-forge
# nbclient                  0.10.2             pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.16.6             pyh29332c3_0    conda-forge
# nbformat                  5.10.4             pyhd8ed1ab_1    conda-forge
# ncurses                   6.5                  h5e97a16_3    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_1    conda-forge
# networkx                  3.4                pyhd8ed1ab_0    conda-forge
# nlohmann_json             3.12.0               ha1acc90_0    conda-forge
# nltk                      3.9.1                    pypi_0    pypi
# nomkl                     1.0                  h5ca1d4c_0    conda-forge
# notebook                  7.1.3              pyhd8ed1ab_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_1    conda-forge
# nspr                      4.36                 h5833ebf_0    conda-forge
# nss                       3.111                ha3c76ea_0    conda-forge
# numba                     0.60.0          py310h0628f0e_0    conda-forge
# numpy                     1.23.5          py310h5d7c261_0    conda-forge
# omegaconf                 2.3.0              pyhd8ed1ab_0    conda-forge
# openai                    1.86.0             pyhd8ed1ab_0    conda-forge
# opencv-python             4.11.0.86                pypi_0    pypi
# openjpeg                  2.5.3                h8a3d83b_0    conda-forge
# openpyxl                  3.1.5           py310h0e452f4_1    conda-forge
# openssl                   3.5.1                h81ee809_0    conda-forge
# opentelemetry-api         1.34.1                   pypi_0    pypi
# opt_einsum                3.4.0              pyhd8ed1ab_1    conda-forge
# optree                    0.15.0          py310h7f4e7e6_0    conda-forge
# optuna                    4.3.0              pyhd8ed1ab_0    conda-forge
# orc                       2.1.1                h74f7c94_0    conda-forge
# ordered-set               4.0.2                    pypi_0    pypi
# orjson                    3.10.18                  pypi_0    pypi
# overrides                 7.7.0              pyhd8ed1ab_1    conda-forge
# packaging                 24.2               pyhd8ed1ab_2    conda-forge
# pandas                    1.5.3           py310h2b830bf_1    conda-forge
# pandas-profiling          3.6.3              pyhd8ed1ab_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# pango                     1.56.3               h5fd7515_1    conda-forge
# parso                     0.8.4              pyhd8ed1ab_1    conda-forge
# pathspec                  0.12.1                   pypi_0    pypi
# patsy                     1.0.1              pyhd8ed1ab_1    conda-forge
# pcre2                     10.45                ha881caa_0    conda-forge
# pdf2image                 1.17.0             pyhd8ed1ab_1    conda-forge
# pdfminer.six              20221105           pyhd8ed1ab_0    conda-forge
# pdfplumber                0.9.0              pyhd8ed1ab_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_1    conda-forge
# phik                      0.12.4          py310h9ce17ec_0    conda-forge
# pickleshare               0.7.5           pyhd8ed1ab_1004    conda-forge
# pillow                    11.1.0          py310h61efb56_0    conda-forge
# pip                       25.1.1             pyh8b19718_0    conda-forge
# pipreqs                   0.5.0                    pypi_0    pypi
# pixman                    0.46.2               h2f9eb0b_0    conda-forge
# pkg-config                0.29.2            hde07d2e_1009    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_2    conda-forge
# platformdirs              4.3.7                    pypi_0    pypi
# poppler                   25.02.0              ha107087_2    conda-forge
# poppler-data              0.4.12               hd8ed1ab_0    conda-forge
# portalocker               3.2.0           py310hbe9552e_0    conda-forge
# prometheus-cpp            1.3.0                h0967b3e_0    conda-forge
# prometheus_client         0.22.1             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.51             pyha770c72_0    conda-forge
# propcache                 0.3.1           py310hc74094e_0    conda-forge
# proto-plus                1.26.1             pyhd8ed1ab_0    conda-forge
# protobuf                  6.31.1                   pypi_0    pypi
# psutil                    7.0.0           py310h078409c_0    conda-forge
# psycopg2-binary           2.9.10                   pypi_0    pypi
# pthread-stubs             0.4               hd74edd7_1002    conda-forge
# ptyprocess                0.7.0              pyhd8ed1ab_1    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_1    conda-forge
# py-xgboost                3.0.2           cpu_pyhc5f55e3_0    conda-forge
# pyarrow                   19.0.1          py310hb6292c7_0    conda-forge
# pyarrow-core              19.0.1          py310hc17921c_0_cpu    conda-forge
# pyarrow-hotfix            0.7                pyhd8ed1ab_0    conda-forge
# pyasn1                    0.6.1              pyhd8ed1ab_2    conda-forge
# pyasn1-modules            0.4.2              pyhd8ed1ab_0    conda-forge
# pybind11                  2.13.6             pyhc790b64_3    conda-forge
# pybind11-global           2.13.6             pyh217bc35_3    conda-forge
# pyboxen                   1.3.0                    pypi_0    pypi
# pycocotools               2.0.10          py310hc12b6d3_0    conda-forge
# pycparser                 2.22               pyh29332c3_1    conda-forge
# pydantic                  2.11.7                   pypi_0    pypi
# pydantic-core             2.33.2          py310hb4f9fe2_0    conda-forge
# pydeck                    0.8.0              pyhd8ed1ab_0    conda-forge
# pydot                     4.0.1           py310hbe9552e_0    conda-forge
# pygments                  2.19.1             pyhd8ed1ab_0    conda-forge
# pyjwt                     2.10.1                   pypi_0    pypi
# pyobjc-core               11.1            py310h3532944_0    conda-forge
# pyobjc-framework-cocoa    11.1            py310h4e4eb3c_0    conda-forge
# pyopenssl                 25.0.0             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.2.3              pyhd8ed1ab_1    conda-forge
# pyrfc3339                 2.0.1                    pypi_0    pypi
# pysocks                   1.7.1              pyha55dd90_7    conda-forge
# pytesseract               0.3.13             pyhd8ed1ab_1    conda-forge
# python                    3.10.17         h6cefb37_0_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhff2d567_1    conda-forge
# python-dotenv             1.1.1                    pypi_0    pypi
# python-fastjsonschema     2.21.1             pyhd8ed1ab_0    conda-forge
# python-flatbuffers        25.2.10            pyhbc23db3_0    conda-forge
# python-json-logger        2.0.4                    pypi_0    pypi
# python-tzdata             2025.2             pyhd8ed1ab_0    conda-forge
# python-xxhash             3.5.0           py310h078409c_2    conda-forge
# python_abi                3.10                    7_cp310    conda-forge
# pytorch                   2.6.0           cpu_generic_py310_h3625fd7_1    conda-forge
# pytorch-crf               0.7.2                    pypi_0    pypi
# pytz                      2022.7.1                 pypi_0    pypi
# pyu2f                     0.1.5              pyhd8ed1ab_1    conda-forge
# pywavelets                1.8.0           py310hc12b6d3_0    conda-forge
# pyyaml                    6.0.2           py310hc74094e_2    conda-forge
# pyzmq                     26.4.0                   pypi_0    pypi
# qhull                     2020.2               h420ef59_5    conda-forge
# rav1e                     0.7.1                h0716509_3    conda-forge
# re2                       2024.07.02           h6589ca4_2    conda-forge
# readline                  8.2                  h1d1bf99_2    conda-forge
# redis                     5.2.1                    pypi_0    pypi
# referencing               0.36.2             pyh29332c3_0    conda-forge
# regex                     2024.11.6       py310h078409c_0    conda-forge
# requests                  2.28.2             pyhd8ed1ab_1    conda-forge
# requests-file             2.1.0                    pypi_0    pypi
# requests-mock             1.12.1                   pypi_0    pypi
# requests-toolbelt         1.0.0                    pypi_0    pypi
# rfc3339-validator         0.1.4              pyhd8ed1ab_1    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# rich                      14.0.0             pyh29332c3_0    conda-forge
# rpds-py                   0.25.1          py310hb4f9fe2_0    conda-forge
# rq                        1.16.2                   pypi_0    pypi
# rsa                       4.9.1              pyhd8ed1ab_0    conda-forge
# rstr                      3.2.2                    pypi_0    pypi
# rules                     3.4                      pypi_0    pypi
# s3transfer                0.13.0                   pypi_0    pypi
# safetensors               0.5.3           py310hde4708a_0    conda-forge
# scikit-learn              1.6.1           py310h48c93d9_0    conda-forge
# scipy                     1.9.3           py310ha0d8a01_2    conda-forge
# seaborn                   0.12.2               hd8ed1ab_0    conda-forge
# seaborn-base              0.12.2             pyhd8ed1ab_0    conda-forge
# semver                    3.0.4                    pypi_0    pypi
# send2trash                1.8.3              pyh31c8845_1    conda-forge
# sentence-transformers     5.0.0              pyhd8ed1ab_0    conda-forge
# sentry-sdk                2.30.0                   pypi_0    pypi
# setuptools                80.1.0             pyhff2d567_0    conda-forge
# shap                      0.48.0          cpu_py310h97e2f2e_1    conda-forge
# six                       1.17.0             pyhd8ed1ab_0    conda-forge
# sleef                     3.8                  h8391f65_0    conda-forge
# slicer                    0.0.8              pyhd8ed1ab_0    conda-forge
# smart_open                7.1.0              pyhd8ed1ab_0    conda-forge
# smmap                     5.0.2              pyhd8ed1ab_0    conda-forge
# snappy                    1.2.1                h98b9ce2_1    conda-forge
# sniffio                   1.3.1              pyhd8ed1ab_1    conda-forge
# soupsieve                 2.7                pyhd8ed1ab_0    conda-forge
# sqlalchemy                2.0.41          py310h078409c_0    conda-forge
# sqlparse                  0.5.3                    pypi_0    pypi
# stack_data                0.6.3              pyhd8ed1ab_1    conda-forge
# statsmodels               0.13.5          py310hf1a086a_2    conda-forge
# streamlit                 1.45.1             pyhd8ed1ab_0    conda-forge
# svt-av1                   3.0.2                h8ab69cd_0    conda-forge
# sympy                     1.14.0           pyh2585a3b_105    conda-forge
# tabulate                  0.9.0              pyhd8ed1ab_2    conda-forge
# tangled-up-in-unicode     0.2.0              pyhd8ed1ab_1    conda-forge
# tenacity                  9.1.2              pyhd8ed1ab_0    conda-forge
# tensorboard               2.18.0             pyhd8ed1ab_1    conda-forge
# tensorboard-data-server   0.7.0           py310hddb97a1_2    conda-forge
# tensorflow                2.18.0          cpu_py310hd689282_0    conda-forge
# tensorflow-base           2.18.0          cpu_py310h6d81f97_0    conda-forge
# tensorflow-estimator      2.18.0          cpu_py310hbadf5a4_0    conda-forge
# termcolor                 3.1.0              pyhd8ed1ab_0    conda-forge
# terminado                 0.18.1             pyh31c8845_0    conda-forge
# tf-keras                  2.18.0             pyhd8ed1ab_0    conda-forge
# threadpoolctl             3.6.0              pyhecae5ae_0    conda-forge
# tiktoken                  0.9.0                    pypi_0    pypi
# tinycss2                  1.1.1                    pypi_0    pypi
# tk                        8.6.13               h5083fa2_1    conda-forge
# tldextract                5.3.0                    pypi_0    pypi
# tokenizers                0.21.1          py310h5c49f5a_0    conda-forge
# toml                      0.10.2             pyhd8ed1ab_1    conda-forge
# tomli                     2.2.1              pyhd8ed1ab_1    conda-forge
# torchcrf                  1.1.0                    pypi_0    pypi
# torchvision               0.21.0          cpu_py310_hc307cfc_1    conda-forge
# torchvision-extra-decoders 0.0.2           py310ha3957cf_2    conda-forge
# tornado                   6.4.2           py310h078409c_0    conda-forge
# tqdm                      4.64.1             pyhd8ed1ab_0    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_1    conda-forge
# transformers              4.51.3             pyhd8ed1ab_0    conda-forge
# typeguard                 2.13.3             pyhd8ed1ab_0    conda-forge
# types-python-dateutil     2.9.0.20250516     pyhd8ed1ab_0    conda-forge
# typing-extensions         4.13.2               h0e9735f_0    conda-forge
# typing-inspection         0.4.1              pyhd8ed1ab_0    conda-forge
# typing_extensions         4.13.2             pyh29332c3_0    conda-forge
# typing_utils              0.1.0              pyhd8ed1ab_1    conda-forge
# tzdata                    2025b                h78e105d_0    conda-forge
# ua-parser                 1.0.1                    pypi_0    pypi
# ua-parser-builtins        0.18.0.post1             pypi_0    pypi
# ujson                     5.10.0                   pypi_0    pypi
# unicodedata2              16.0.0          py310h078409c_0    conda-forge
# uri-template              1.3.0              pyhd8ed1ab_1    conda-forge
# uritemplate               4.2.0                    pypi_0    pypi
# urllib3                   1.26.20                  pypi_0    pypi
# user-agents               2.2.0                    pypi_0    pypi
# visions                   0.7.5           py310hca03da5_0
# wand                      0.6.10             pyhd8ed1ab_0    conda-forge
# watchdog                  6.0.0           py310h078409c_0    conda-forge
# wcwidth                   0.2.13             pyhd8ed1ab_1    conda-forge
# webcolors                 24.11.1            pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_3    conda-forge
# websocket-client          1.8.0              pyhd8ed1ab_1    conda-forge
# werkzeug                  2.0.2                    pypi_0    pypi
# wheel                     0.40.0                   pypi_0    pypi
# widgetsnbextension        4.0.14             pyhd8ed1ab_0    conda-forge
# wrapt                     1.17.2          py310h078409c_0    conda-forge
# x265                      3.5                  hbc6ce65_3    conda-forge
# xgboost                   3.0.2           cpu_pyhc1a9e11_0    conda-forge
# xmljson                   0.2.1                    pypi_0    pypi
# xorg-libice               1.1.2                h5505292_0    conda-forge
# xorg-libsm                1.2.6                h5505292_0    conda-forge
# xorg-libx11               1.8.12               h6a5fb8c_0    conda-forge
# xorg-libxau               1.0.12               h5505292_0    conda-forge
# xorg-libxdmcp             1.1.5                hd74edd7_0    conda-forge
# xorg-libxext              1.3.6                hd74edd7_0    conda-forge
# xorg-libxrender           0.9.12               h5505292_0    conda-forge
# xorg-libxt                1.3.1                h5505292_0    conda-forge
# xxhash                    0.8.3                haa4e116_0    conda-forge
# yacs                      0.1.8              pyh29332c3_2    conda-forge
# yaml                      0.2.5                h3422bc3_2    conda-forge
# yarg                      0.1.9                    pypi_0    pypi
# yarl                      1.20.0          py310hc74094e_0    conda-forge
# zeromq                    4.3.5                hc1bb282_7    conda-forge
# zipp                      3.21.0             pyhd8ed1ab_1    conda-forge
# zlib                      1.3.1                h8359307_2    conda-forge
# zstandard                 0.23.0          py310h078409c_2    conda-forge
# zstd                      1.5.7                h6491c7d_2    conda-forge
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show pandas
# Out:
# Name: pandas
# Version: 1.5.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: The Pandas Development Team
# Author-email: pandas-dev@python.org
# License: BSD-3-Clause
# Location: /opt/anaconda3/envs/clean_nlp_env/lib/python3.10/site-packages
# Requires: numpy, python-dateutil, pytz
# Required-by: category_encoders, datasets, label-studio, label-studio-sdk, pandas-profiling, phik, seaborn, shap, statsmodels, streamlit, visions
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.6.1'

# %%
import joblib

# %%
joblib.__version__
# Out:
# '1.5.0'

# %%
np.__version__
# Out:
# '1.23.5'

# %%
# !python --version
# Out:
# Python 3.12.2

# %%
ce.__version__
# Out:
# '2.8.1'
