# %%
import pandas as pd
location_df = pd.read_csv("datasets/location_df.csv")
print("location_df shape:", location_df.shape)
print("columns sample:", location_df.columns[:5].tolist())
print("sample row:", location_df.head(1))
# Out:
# location_df shape: (246, 1071)
# columns sample: ['PropertyName', 'Shree Krishna Hospital', 'Sahara Mall', 'Miracles Apollo Cradle Hospital', 'Medanta Dialysis Center']
# sample row:          PropertyName  Shree Krishna Hospital  Sahara Mall  \
# 0  Smartworld One DXP                    54.0         54.0
#
#    Miracles Apollo Cradle Hospital  Medanta Dialysis Center  \
# 0                             54.0                     54.0
#
#    NH 8, Sector 15 Part 2  Global Foyer Mall  Chirag Hospital  \
# 0                    54.0               54.0             54.0
#
#    iON Digital Zone, Gurgaon  Le Meridien Gurgaon  ...  \
# 0                       54.0                 54.0  ...
#
#    Naurangpur Cricket Stadium  Golf course extension road  \
# 0                        54.0                        54.0
#
#    Old Delhi Gurgaon Road  Iffco Chowk Metro Station  Khatu Shyam Mandir  \
# 0                    54.0                       54.0                54.0
#
# ...

# %%
from utils import recommend_properties_with_finalSimValue
# test with any property name from location_df
sample = location_df['PropertyName'].iloc[0]
result = recommend_properties_with_finalSimValue(sample)
print("result columns:", result.columns.tolist())
print("result sample:\n", result.head(3))
# Out:
# result columns: ['PropertyName']
# result sample:
#        PropertyName
# 29      BPTP Terra
# 16  M3M Golf Hills
# 77  DLF Park Place
